# %%
import re

# Verilen içerik
content = '''
{"showTypeColor":false,"sizeProperty":false,"skuPropertyValues":[{"skuColorValue":"#000000","skuPropertyTips":"Black","propertyValueName":"Black","propertyValueId":193,"skuPropertyImagePath":"https://ae01.alicdn.com/kf/H8826d6033b704cd7b711a92172b5fff2p/Okuma-g-zl-mavi-k-engelleme-bilgisayar-okuyucular-kad-nlar-erkekler-i-in-Anti-parlama-UV.jpg_640x640.jpg","skuPropertyValueTips":"Black","skuPropertyValueShowOrder":1,"propertyValueDefinitionName":"Black","propertyValueIdLong":193,"skuPropertyImageSummPath":"https://ae01.alicdn.com/kf/H8826d6033b704cd7b711a92172b5fff2p/Okuma-g-zl-mavi-k-engelleme-bilgisayar-okuyucular-kad-nlar-erkekler-i-in-Anti-parlama-UV.jpg_80x80.jpg","propertyValueDisplayName":"Black"},{"skuColorValue":"#FF0000","skuPropertyTips":"Red","propertyValueName":"Kırmızı","propertyValueId":10,"skuPropertyImagePath":"https://ae01.alicdn.com/kf/H391abb9512c341c9b092fd34852bbd47J/Okuma-g-zl-mavi-k-engelleme-bilgisayar-okuyucular-kad-nlar-erkekler-i-in-Anti-parlama-UV.jpg_640x640.jpg","skuPropertyValueTips":"Red","skuPropertyValueShowOrder":1,"propertyValueDefinitionName":"Red","propertyValueIdLong":10,"skuPropertyImageSummPath":"https://ae01.alicdn.com/kf/H391abb9512c341c9b092fd34852bbd47J/Okuma-g-zl-mavi-k-engelleme-bilgisayar-okuyucular-kad-nlar-erkekler-i-in-Anti-parlama-UV.jpg_80x80.jpg","propertyValueDisplayName":"Red"},{"skuColorValue":"#0080FF","skuPropertyTips":"Blue","propertyValueName":"Mavi","propertyValueId":173,"skuPropertyImagePath":"https://ae01.alicdn.com/kf/H02d294b45615409c80a7092454ef8368s/Okuma-g-zl-mavi-k-engelleme-bilgisayar-okuyucular-kad-nlar-erkekler-i-in-Anti-parlama-UV.jpg_640x640.jpg","skuPropertyValueTips":"Blue","skuPropertyValueShowOrder":1,"propertyValueDefinitionName":"Blue","propertyValueIdLong":173,"skuPropertyImageSummPath":"https://ae01.alicdn.com/kf/H02d294b45615409c80a7092454ef8368s/Okuma-g-zl-mavi-k-engelleme-bilgisayar-okuyucular-kad-nlar-erkekler-i-in-Anti-parlama-UV.jpg_80x80.jpg","propertyValueDisplayName":"Blue"},{"skuColorValue":"#6C3365","skuPropertyTips":"purple","propertyValueName":"Mor","propertyValueId":496,"skuPropertyImagePath":"https://ae01.alicdn.com/kf/H177137b2ec734cf09761c76c11b79372g/Okuma-g-zl-mavi-k-engelleme-bilgisayar-okuyucular-kad-nlar-erkekler-i-in-Anti-parlama-UV.jpg_640x640.jpg","skuPropertyValueTips":"purple","skuPropertyValueShowOrder":1,"propertyValueDefinitionName":"purple","propertyValueIdLong":496,"skuPropertyImageSummPath":"https://ae01.alicdn.com/kf/H177137b2ec734cf09761c76c11b79372g/Okuma-g-zl-mavi-k-engelleme-bilgisayar-okuyucular-kad-nlar-erkekler-i-in-Anti-parlama-UV.jpg_80x80.jpg","propertyValueDisplayName":"purple"},{"skuColorValue":"#E47911","skuPropertyTips":"tawny","propertyValueName":"Tawny","propertyValueId":202909806,"skuPropertyImagePath":"https://ae01.alicdn.com/kf/H496d8784790048fd9be048e9d9cea553i/Okuma-g-zl-mavi-k-engelleme-bilgisayar-okuyucular-kad-nlar-erkekler-i-in-Anti-parlama-UV.jpg_640x640.jpg","skuPropertyValueTips":"tawny","skuPropertyValueShowOrder":1,"propertyValueDefinitionName":"tawny","propertyValueIdLong":202909806,"skuPropertyImageSummPath":"https://ae01.alicdn.com/kf/H496d8784790048fd9be048e9d9cea553i/Okuma-g-zl-mavi-k-engelleme-bilgisayar-okuyucular-kad-nlar-erkekler-i-in-Anti-parlama-UV.jpg_80x80.jpg","propertyValueDisplayName":"tawny"},{"skuColorValue":"#855C33","skuPropertyTips":"testudinarious","propertyValueName":"Dark Brown","propertyValueId":6146,"skuPropertyImagePath":"https://ae01.alicdn.com/kf/H4921155438934b9b905f8716ad7c2067L/Okuma-g-zl-mavi-k-engelleme-bilgisayar-okuyucular-kad-nlar-erkekler-i-in-Anti-parlama-UV.jpg_640x640.jpg","skuPropertyValueTips":"testudinarious","skuPropertyValueShowOrder":1,"propertyValueDefinitionName":"testudinarious","propertyValueIdLong":6146,"skuPropertyImageSummPath":"https://ae01.alicdn.com/kf/H4921155438934b9b905f8716ad7c2067L/Okuma-g-zl-mavi-k-engelleme-bilgisayar-okuyucular-kad-nlar-erkekler-i-in-Anti-parlama-UV.jpg_80x80.jpg","propertyValueDisplayName":"testudinarious"}],"showType":"none","skuPropertyName":"çerçeve Rengi"}
'''

# Detail1 için regex deseni
detail1_pattern = re.compile(r'"skuColorValue":"#(?:[0-9a-fA-F]{3}){1,2}","skuPropertyTips":"(.*?)","propertyValueName":"(?:.*?)","propertyValueId":(\d+),"skuPropertyImagePath":"(.*?)".*?')

# Tüm detail1 eşleşmelerini bul
details1 = detail1_pattern.findall(content)

# Her bir detail1 öğesini işle
for detail1 in details1:
    skuPropertyTips = detail1[0]
    propertyValueId = detail1[1]
    skuPropertyImagePath = detail1[2]

    print("SKU Property Tips:", skuPropertyTips)
    print("propertyValueId:", propertyValueId)
    print("SKU Property Image Path:", skuPropertyImagePath)
    print("-" * 50)
# Out:
# SKU Property Tips: Black
# propertyValueId: 193
# SKU Property Image Path: https://ae01.alicdn.com/kf/H8826d6033b704cd7b711a92172b5fff2p/Okuma-g-zl-mavi-k-engelleme-bilgisayar-okuyucular-kad-nlar-erkekler-i-in-Anti-parlama-UV.jpg_640x640.jpg
# --------------------------------------------------
# SKU Property Tips: Red
# propertyValueId: 10
# SKU Property Image Path: https://ae01.alicdn.com/kf/H391abb9512c341c9b092fd34852bbd47J/Okuma-g-zl-mavi-k-engelleme-bilgisayar-okuyucular-kad-nlar-erkekler-i-in-Anti-parlama-UV.jpg_640x640.jpg
# --------------------------------------------------
# SKU Property Tips: Blue
# propertyValueId: 173
# SKU Property Image Path: https://ae01.alicdn.com/kf/H02d294b45615409c80a7092454ef8368s/Okuma-g-zl-mavi-k-engelleme-bilgisayar-okuyucular-kad-nlar-erkekler-i-in-Anti-parlama-UV.jpg_640x640.jpg
# --------------------------------------------------
# SKU Property Tips: purple
# propertyValueId: 496
# ...

# %%
import re

# Verilen içerik
content = '''
{"skuComponent":{"selectedSkuAttr":"200006449:200660896;71:173#Blue","hasSkuProperty":true,"productSKUPropertyList":[{"showTypeColor":false,"sizeProperty":false,"skuPropertyValues":[{"skuPropertyTips":"0","propertyValueName":"0","propertyValueId":350697,"skuPropertyValueTips":"0","skuPropertyValueShowOrder":2,"propertyValueIdLong":350697,"propertyValueDisplayName":"0"},{"skuPropertyTips":"+ 50","propertyValueName":"+ 50","propertyValueId":202041810,"skuPropertyValueTips":"+ 50","skuPropertyValueShowOrder":2,"propertyValueIdLong":202041810,"propertyValueDisplayName":"+ 50"},{"skuPropertyTips":"+ 75","propertyValueName":"+ 75","propertyValueId":202041811,"skuPropertyValueTips":"+ 75","skuPropertyValueShowOrder":2,"propertyValueIdLong":202041811,"propertyValueDisplayName":"+ 75"},{"skuPropertyTips":"+100","propertyValueName":"+100","propertyValueId":200660889,"skuPropertyValueTips":"+100","skuPropertyValueShowOrder":2,"propertyValueIdLong":200660889,"propertyValueDisplayName":"+100"},{"skuPropertyTips":"+ 125","propertyValueName":"+ 125","propertyValueId":202041806,"skuPropertyValueTips":"+ 125","skuPropertyValueShowOrder":2,"propertyValueIdLong":202041806,"propertyValueDisplayName":"+ 125"},{"skuPropertyTips":"+150","propertyValueName":"+150","propertyValueId":200660890,"skuPropertyValueTips":"+150","skuPropertyValueShowOrder":2,"propertyValueIdLong":200660890,"propertyValueDisplayName":"+150"},{"skuPropertyTips":"+ 175","propertyValueName":"+ 175","propertyValueId":202041807,"skuPropertyValueTips":"+ 175","skuPropertyValueShowOrder":2,"propertyValueIdLong":202041807,"propertyValueDisplayName":"+ 175"},{"skuPropertyTips":"+200","propertyValueName":"+200","propertyValueId":200660891,"skuPropertyValueTips":"+200","skuPropertyValueShowOrder":2,"propertyValueIdLong":200660891,"propertyValueDisplayName":"+200"},{"skuPropertyTips":"+ 225","propertyValueName":"+ 225","propertyValueId":202041808,"skuPropertyValueTips":"+ 225","skuPropertyValueShowOrder":2,"propertyValueIdLong":202041808,"propertyValueDisplayName":"+ 225"},{"skuPropertyTips":"+250","propertyValueName":"+250","propertyValueId":200660892,"skuPropertyValueTips":"+250","skuPropertyValueShowOrder":2,"propertyValueIdLong":200660892,"propertyValueDisplayName":"+250"},{"skuPropertyTips":"+ 275","propertyValueName":"+ 275","propertyValueId":202041809,"skuPropertyValueTips":"+ 275","skuPropertyValueShowOrder":2,"propertyValueIdLong":202041809,"propertyValueDisplayName":"+ 275"},{"skuPropertyTips":"+300","propertyValueName":"+300","propertyValueId":200660893,"skuPropertyValueTips":"+300","skuPropertyValueShowOrder":2,"propertyValueIdLong":200660893,"propertyValueDisplayName":"+300"},{"skuPropertyTips":"+350","propertyValueName":"+350","propertyValueId":200660894,"skuPropertyValueTips":"+350","skuPropertyValueShowOrder":2,"propertyValueIdLong":200660894,"propertyValueDisplayName":"+350"},{"skuPropertyTips":"+ 450","propertyValueName":"+ 450","propertyValueId":202081806,"skuPropertyValueTips":"+ 450","skuPropertyValueShowOrder":2,"propertyValueIdLong":202081806,"propertyValueDisplayName":"+ 450"},{"skuPropertyTips":"+500","propertyValueName":"+500","propertyValueId":200660896,"skuPropertyValueTips":"+500","skuPropertyValueShowOrder":2,"propertyValueIdLong":200660896,"propertyValueDisplayName":"+500"},{"skuPropertyTips":"+ 600","propertyValueName":"+ 600","propertyValueId":202081807,"skuPropertyValueTips":"+ 600","skuPropertyValueShowOrder":2,"propertyValueIdLong":202081807,"propertyValueDisplayName":"+ 600"}]}],"showType":"none","skuPropertyName":"çerçeve Rengi"}}
'''

# Detail2 için regex deseni
detail2_pattern = re.compile(r'"skuPropertyTips":"(.*?)","propertyValueId":(\d+),.*?')

# Tüm detail2 eşleşmelerini bul
details2 = detail2_pattern.findall(content)

# Her bir detail2 öğesini işle
for detail2 in details2:
    skuPropertyTips = detail2[0]
    propertyValueId = detail2[1]

    print("SKU Property Tips:", skuPropertyTips)
    print("propertyValueId:", propertyValueId)
    print("-" * 50)
# Out:
# SKU Property Tips: 0","propertyValueName":"0
# propertyValueId: 350697
# --------------------------------------------------
# SKU Property Tips: + 50","propertyValueName":"+ 50
# propertyValueId: 202041810
# --------------------------------------------------
# SKU Property Tips: + 75","propertyValueName":"+ 75
# propertyValueId: 202041811
# --------------------------------------------------
# SKU Property Tips: +100","propertyValueName":"+100
# propertyValueId: 200660889
# --------------------------------------------------
# SKU Property Tips: + 125","propertyValueName":"+ 125
# propertyValueId: 202041806
# --------------------------------------------------
# SKU Property Tips: +150","propertyValueName":"+150
# propertyValueId: 200660890
# --------------------------------------------------
# SKU Property Tips: + 175","propertyValueName":"+ 175
# propertyValueId: 202041807
# --------------------------------------------------
# SKU Property Tips: +200","propertyValueName":"+200
# ...

# %%
import requests
from bs4 import BeautifulSoup
import re

# Web sayfasının URL'si
url = 'https://tr.aliexpress.com/item/1005005988698660.html?spm=a2g0o.categorymp.prodcutlist.51.37a1rvgrrvgrk1&pdp_ext_f=%7B%22sku_id%22%3A%2212000035198564762%22%7D&utparam-url=scene%3Asearch%7Cquery_from%3A'

response = requests.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    scripts = soup.find_all('script')
    for script in scripts: 
        if 'window.runParams' in script.text: 
            break  
else:
    print("Hata")

    # Detail1 için regex deseni
detail1_pattern = re.compile(r'"skuColorValue":"#(?:[0-9a-fA-F]{3}){1,2}","skuPropertyTips":"(.*?)","propertyValueName":"(?:.*?)","propertyValueId":(\d+),"skuPropertyImagePath":"(.*?)".*?')

# Tüm detail1 eşleşmelerini bul
details1 = detail1_pattern.findall( script.text)

# Her bir detail1 öğesini işle
for detail1 in details1:
    skuPropertyTips = detail1[0]
    propertyValueId = detail1[1]
    skuPropertyImagePath = detail1[2]

    print("SKU Property Tips:", skuPropertyTips)
    print("propertyValueId:", propertyValueId)
    print("SKU Property Image Path:", skuPropertyImagePath)
    print("-" * 50)
    

# Tüm detail2 eşleşmelerini bul
details2 = detail2_pattern.findall(script.text)

# Detail2 için regex deseni
detail2_pattern = re.compile(r'"skuPropertyTips":"(.*?)","propertyValueId":(\d+),.*?')

# Her bir detail2 öğesini işle
for detail2 in details2:
    skuPropertyTips = detail2[0]
    propertyValueId = detail2[1]

    print("SKU Property Tips:", skuPropertyTips)
    print("propertyValueId:", propertyValueId)
    print("-" * 50)
# Out:
# SKU Property Tips: YELLOW
# propertyValueId: 366
# SKU Property Image Path: https://ae01.alicdn.com/kf/Sdd1ce09646804651ac56512b5be9c8932/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_640x640.jpg
# --------------------------------------------------
# SKU Property Tips: Rose Red
# propertyValueId: 200004891
# SKU Property Image Path: https://ae01.alicdn.com/kf/S0913966f68394c72a9ea4f7883809354H/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_640x640.jpg
# --------------------------------------------------
# SKU Property Tips: Pembe
# propertyValueId: 1052
# SKU Property Image Path: https://ae01.alicdn.com/kf/Sa850466f75124bd98f9faaac976035c56/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_640x640.jpg
# --------------------------------------------------
# SKU Property Tips: Mor
# propertyValueId: 496
# ...

# %%
import json

# JSON verisini tanımlama
json_data = '''
{
    "skuComponent": {
        "selectedSkuAttr": "14:366;5:200003528",
        "hasSkuProperty": true,
        "productSKUPropertyList": [
            {
                "showTypeColor": true,
                "sizeProperty": false,
                "skuPropertyValues": [
                    {
                        "skuColorValue": "#FFFF00",
                        "skuPropertyTips": "YELLOW",
                        "propertyValueName": "YELLOW",
                        "propertyValueId": 366,
                        "skuPropertyImagePath": "https://ae01.alicdn.com/kf/Sdd1ce09646804651ac56512b5be9c8932/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_640x640.jpg",
                        "skuPropertyValueTips": "YELLOW",
                        "skuPropertyValueShowOrder": 1,
                        "propertyValueIdLong": 366,
                        "skuPropertyImageSummPath": "https://ae01.alicdn.com/kf/Sdd1ce09646804651ac56512b5be9c8932/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_80x80.jpg",
                        "propertyValueDisplayName": "YELLOW"
                    },
                    {
                        "skuColorValue": "#DDA0DD",
                        "skuPropertyTips": "Rose Red",
                        "propertyValueName": "Lavanta",
                        "propertyValueId": 200004891,
                        "skuPropertyImagePath": "https://ae01.alicdn.com/kf/S0913966f68394c72a9ea4f7883809354H/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_640x640.jpg",
                        "skuPropertyValueTips": "Rose Red",
                        "skuPropertyValueShowOrder": 1,
                        "propertyValueDefinitionName": "Rose Red",
                        "propertyValueIdLong": 200004891,
                        "skuPropertyImageSummPath": "https://ae01.alicdn.com/kf/S0913966f68394c72a9ea4f7883809354H/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_80x80.jpg",
                        "propertyValueDisplayName": "Rose Red"
                    },
                    {
                        "skuColorValue": "#FFC0CB",
                        "skuPropertyTips": "Pembe",
                        "propertyValueName": "Pembe",
                        "propertyValueId": 1052,
                        "skuPropertyImagePath": "https://ae01.alicdn.com/kf/Sa850466f75124bd98f9faaac976035c56/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_640x640.jpg",
                        "skuPropertyValueTips": "Pembe",
                        "skuPropertyValueShowOrder": 1,
                        "propertyValueIdLong": 1052,
                        "skuPropertyImageSummPath": "https://ae01.alicdn.com/kf/Sa850466f75124bd98f9faaac976035c56/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_80x80.jpg",
                        "propertyValueDisplayName": "Pembe"
                    },
                    {
                        "skuColorValue": "#6C3365",
                        "skuPropertyTips": "Mor",
                        "propertyValueName": "Mor",
                        "propertyValueId": 496,
                        "skuPropertyImagePath": "https://ae01.alicdn.com/kf/Sf3df6c7b12ec497996cd7a4ac60baf00V/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_640x640.jpg",
                        "skuPropertyValueTips": "Mor",
                        "skuPropertyValueShowOrder": 1,
                        "propertyValueIdLong": 496,
                        "skuPropertyImageSummPath": "https://ae01.alicdn.com/kf/Sf3df6c7b12ec497996cd7a4ac60baf00V/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_80x80.jpg",
                        "propertyValueDisplayName": "Mor"
                    },
                    {
                        "skuColorValue": "#0080FF",
                        "skuPropertyTips": "Mavi",
                        "propertyValueName": "Mavi",
                        "propertyValueId": 173,
                        "skuPropertyImagePath": "https://ae01.alicdn.com/kf/S864b48f43fa54df8a58629d86a01232aQ/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_640x640.jpg",
                        "skuPropertyValueTips": "Mavi",
                        "skuPropertyValueShowOrder": 1,
                        "propertyValueIdLong": 173,
                        "skuPropertyImageSummPath": "https://ae01.alicdn.com/kf/S864b48f43fa54df8a58629d86a01232aQ/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_80x80.jpg",
                        "propertyValueDisplayName": "Mavi"
                    },
                    {
                        "skuPropertyTips": "Dark Yellow",
                        "propertyValueName": "Koyu haki",
                        "propertyValueId": 200006154,
                        "skuPropertyImagePath": "https://ae01.alicdn.com/kf/S7461ad94f62e47d18c7f994de06b22233/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_640x640.jpg",
                        "skuPropertyValueTips": "Dark Yellow",
                        "skuPropertyValueShowOrder": 1,
                        "propertyValueDefinitionName": "Dark Yellow",
                        "propertyValueIdLong": 200006154,
                        "skuPropertyImageSummPath": "https://ae01.alicdn.com/kf/S7461ad94f62e47d18c7f994de06b22233/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_80x80.jpg",
                        "propertyValueDisplayName": "Dark Yellow"
                    },
                    {
                        "skuColorValue": "#8D6468",
                        "skuPropertyTips": "Orange",
                        "propertyValueName": "Kahverengi",
                        "propertyValueId": 365458,
                        "skuPropertyImagePath": "https://ae01.alicdn.com/kf/Sffec99f0033e4b9db536dffcb23b83862/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_640x640.jpg",
                        "skuPropertyValueTips": "Orange",
                        "skuPropertyValueShowOrder": 1,
                        "propertyValueDefinitionName": "Orange",
                        "propertyValueIdLong": 365458,
                        "skuPropertyImageSummPath": "https://ae01.alicdn.com/kf/Sffec99f0033e4b9db536dffcb23b83862/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_80x80.jpg",
                        "propertyValueDisplayName": "Orange"
                    }
                ],
                "showType": "colour_atla",
                "skuPropertyName": "Renk",
                "skuPropertyId": 14,
                "isNewStandardSizeChart": false,
                "order": 1
            },
            {
                "showTypeColor": false,
                "sizeProperty": false,
                "skuPropertyValues": [
                    {
                        "skuPropertyTips": "One Size",
                        "propertyValueName": "One Size",
                        "propertyValueId": 200003528,
                        "skuPropertyValueTips": "One Size",
                        "skuPropertyValueShowOrder": 2,
                        "propertyValueIdLong": 200003528,
                        "propertyValueDisplayName": "One Size"
                    }
                ],
                "showType": "none",
                "skuPropertyName": "Boyut",
                "skuPropertyId": 5,
                "isNewStandardSizeChart": false,
                "order": 3
            }
        ],
        "skuPropertyJson": "[[366,200004891,1052,496,173,200006154,365458],[200003528]]"
    }
}
'''

# JSON verisini yükleme
data = json.loads(json_data)

# Seçilen SKU özelliklerini çözümleme
selected_sku_attr = data["skuComponent"]["selectedSkuAttr"]
selected_sku_attr_dict = dict(attr.split(":") for attr in selected_sku_attr.split(";"))

# SKU özellik listesini çözümleme
sku_properties = data["skuComponent"]["productSKUPropertyList"]

# Anlamlı hale getirilmiş verileri saklamak için liste
readable_sku_properties = []

for sku_property in sku_properties:
    sku_property_name = sku_property["skuPropertyName"]
    for value in sku_property["skuPropertyValues"]:
        property_value_id = str(value["propertyValueId"])
        sku_property_info = {
            "Property Name": sku_property_name,
            "Value Name": value["skuPropertyTips"],
            "Property ID": property_value_id
        }
        if "skuPropertyImagePath" in value:
            sku_property_info["Image URL"] = value["skuPropertyImagePath"]
        if property_value_id in selected_sku_attr_dict.values():
            sku_property_info["Selected"] = True
        else:
            sku_property_info["Selected"] = False
        readable_sku_properties.append(sku_property_info)

# Anlamlı hale getirilmiş verileri yazdırma
for prop in readable_sku_properties:
    print(f"{prop['Property Name']} (ID: {prop['Property ID']}): {prop['Value Name']}")
    if "Image URL" in prop:
        print(f"Image URL: {prop['Image URL']}")
    print(f"Selected: {prop['Selected']}")
    print()
# Out:
# Renk (ID: 366): YELLOW
# Image URL: https://ae01.alicdn.com/kf/Sdd1ce09646804651ac56512b5be9c8932/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_640x640.jpg
# Selected: True
#
# Renk (ID: 200004891): Rose Red
# Image URL: https://ae01.alicdn.com/kf/S0913966f68394c72a9ea4f7883809354H/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_640x640.jpg
# Selected: False
#
# Renk (ID: 1052): Pembe
# Image URL: https://ae01.alicdn.com/kf/Sa850466f75124bd98f9faaac976035c56/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_640x640.jpg
# Selected: False
#
# Renk (ID: 496): Mor
# Image URL: https://ae01.alicdn.com/kf/Sf3df6c7b12ec497996cd7a4ac60baf00V/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_640x640.jpg
# Selected: False
#
# Renk (ID: 173): Mavi
# Image URL: https://ae01.alicdn.com/kf/S864b48f43fa54df8a58629d86a01232aQ/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_640x640.jpg
# Selected: False
#
# ...

# %%
import json

# JSON verisini tanımlama
json_data = '''
{
    "skuComponent": {
        "selectedSkuAttr": "14:366;5:200003528",
        "hasSkuProperty": true,
        "productSKUPropertyList": [
            {
                "showTypeColor": true,
                "sizeProperty": false,
                "skuPropertyValues": [
                    {
                        "skuColorValue": "#FFFF00",
                        "skuPropertyTips": "YELLOW",
                        "propertyValueName": "YELLOW",
                        "propertyValueId": 366,
                        "skuPropertyImagePath": "https://ae01.alicdn.com/kf/Sdd1ce09646804651ac56512b5be9c8932/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_640x640.jpg",
                        "skuPropertyValueTips": "YELLOW",
                        "skuPropertyValueShowOrder": 1,
                        "propertyValueIdLong": 366,
                        "skuPropertyImageSummPath": "https://ae01.alicdn.com/kf/Sdd1ce09646804651ac56512b5be9c8932/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_80x80.jpg",
                        "propertyValueDisplayName": "YELLOW"
                    },
                    {
                        "skuColorValue": "#DDA0DD",
                        "skuPropertyTips": "Rose Red",
                        "propertyValueName": "Lavanta",
                        "propertyValueId": 200004891,
                        "skuPropertyImagePath": "https://ae01.alicdn.com/kf/S0913966f68394c72a9ea4f7883809354H/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_640x640.jpg",
                        "skuPropertyValueTips": "Rose Red",
                        "skuPropertyValueShowOrder": 1,
                        "propertyValueDefinitionName": "Rose Red",
                        "propertyValueIdLong": 200004891,
                        "skuPropertyImageSummPath": "https://ae01.alicdn.com/kf/S0913966f68394c72a9ea4f7883809354H/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_80x80.jpg",
                        "propertyValueDisplayName": "Rose Red"
                    },
                    {
                        "skuColorValue": "#FFC0CB",
                        "skuPropertyTips": "Pembe",
                        "propertyValueName": "Pembe",
                        "propertyValueId": 1052,
                        "skuPropertyImagePath": "https://ae01.alicdn.com/kf/Sa850466f75124bd98f9faaac976035c56/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_640x640.jpg",
                        "skuPropertyValueTips": "Pembe",
                        "skuPropertyValueShowOrder": 1,
                        "propertyValueIdLong": 1052,
                        "skuPropertyImageSummPath": "https://ae01.alicdn.com/kf/Sa850466f75124bd98f9faaac976035c56/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_80x80.jpg",
                        "propertyValueDisplayName": "Pembe"
                    },
                    {
                        "skuColorValue": "#6C3365",
                        "skuPropertyTips": "Mor",
                        "propertyValueName": "Mor",
                        "propertyValueId": 496,
                        "skuPropertyImagePath": "https://ae01.alicdn.com/kf/Sf3df6c7b12ec497996cd7a4ac60baf00V/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_640x640.jpg",
                        "skuPropertyValueTips": "Mor",
                        "skuPropertyValueShowOrder": 1,
                        "propertyValueIdLong": 496,
                        "skuPropertyImageSummPath": "https://ae01.alicdn.com/kf/Sf3df6c7b12ec497996cd7a4ac60baf00V/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_80x80.jpg",
                        "propertyValueDisplayName": "Mor"
                    },
                    {
                        "skuColorValue": "#0080FF",
                        "skuPropertyTips": "Mavi",
                        "propertyValueName": "Mavi",
                        "propertyValueId": 173,
                        "skuPropertyImagePath": "https://ae01.alicdn.com/kf/S864b48f43fa54df8a58629d86a01232aQ/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_640x640.jpg",
                        "skuPropertyValueTips": "Mavi",
                        "skuPropertyValueShowOrder": 1,
                        "propertyValueIdLong": 173,
                        "skuPropertyImageSummPath": "https://ae01.alicdn.com/kf/S864b48f43fa54df8a58629d86a01232aQ/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_80x80.jpg",
                        "propertyValueDisplayName": "Mavi"
                    },
                    {
                        "skuPropertyTips": "Dark Yellow",
                        "propertyValueName": "Koyu haki",
                        "propertyValueId": 200006154,
                        "skuPropertyImagePath": "https://ae01.alicdn.com/kf/S7461ad94f62e47d18c7f994de06b22233/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_640x640.jpg",
                        "skuPropertyValueTips": "Dark Yellow",
                        "skuPropertyValueShowOrder": 1,
                        "propertyValueDefinitionName": "Dark Yellow",
                        "propertyValueIdLong": 200006154,
                        "skuPropertyImageSummPath": "https://ae01.alicdn.com/kf/S7461ad94f62e47d18c7f994de06b22233/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_80x80.jpg",
                        "propertyValueDisplayName": "Dark Yellow"
                    },
                    {
                        "skuColorValue": "#8D6468",
                        "skuPropertyTips": "Orange",
                        "propertyValueName": "Kahverengi",
                        "propertyValueId": 365458,
                        "skuPropertyImagePath": "https://ae01.alicdn.com/kf/Sffec99f0033e4b9db536dffcb23b83862/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_640x640.jpg",
                        "skuPropertyValueTips": "Orange",
                        "skuPropertyValueShowOrder": 1,
                        "propertyValueDefinitionName": "Orange",
                        "propertyValueIdLong": 365458,
                        "skuPropertyImageSummPath": "https://ae01.alicdn.com/kf/Sffec99f0033e4b9db536dffcb23b83862/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_80x80.jpg",
                        "propertyValueDisplayName": "Orange"
                    }
                ],
                "showType": "colour_atla",
                "skuPropertyName": "Renk",
                "skuPropertyId": 14,
                "isNewStandardSizeChart": false,
                "order": 1
            },
            {
                "showTypeColor": false,
                "sizeProperty": false,
                "skuPropertyValues": [
                    {
                        "skuPropertyTips": "One Size",
                        "propertyValueName": "One Size",
                        "propertyValueId": 200003528,
                        "skuPropertyValueTips": "One Size",
                        "skuPropertyValueShowOrder": 2,
                        "propertyValueIdLong": 200003528,
                        "propertyValueDisplayName": "One Size"
                    }
                ],
                "showType": "none",
                "skuPropertyName": "Boyut",
                "skuPropertyId": 5,
                "isNewStandardSizeChart": false,
                "order": 3
            }
        ],
        "skuPropertyJson": "[[366,200004891,1052,496,173,200006154,365458],[200003528]]"
    }
}
'''

# JSON verisini yü

# JSON verisini yükleme
data = json.loads(json_data)

# SKU özellik listesini çözümleme
sku_properties = data["skuComponent"]["productSKUPropertyList"]

# Renk ve boyut kombinasyonlarını saklamak için liste
variant_combinations = []

# Renk ve boyut bilgilerini toplama
for color in sku_properties[0]["skuPropertyValues"]:
    for size in sku_properties[1]["skuPropertyValues"]:
        variant = {
            "detail1": {
                "Name": color["skuPropertyTips"],
                "ID": color["propertyValueId"],
                "Image URL": color["skuPropertyImagePath"]
            },
            "detail2": {
                "Name": size["propertyValueName"],
                "ID": size["propertyValueId"]
            }
        }
        variant_combinations.append(variant)

# Her bir kombinasyonu yazdırma
for variant in variant_combinations:
    print(f" {variant['detail1']['Name']} (ID: {variant['detail1']['ID']})")
    print(f"   {variant['detail2']['Name']} (ID: {variant['detail2']['ID']})")
    print(f"    {variant['detail1']['Image URL']}")
    print()
# Out:
#  YELLOW (ID: 366)
#    One Size (ID: 200003528)
#     https://ae01.alicdn.com/kf/Sdd1ce09646804651ac56512b5be9c8932/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_640x640.jpg
#
#  Rose Red (ID: 200004891)
#    One Size (ID: 200003528)
#     https://ae01.alicdn.com/kf/S0913966f68394c72a9ea4f7883809354H/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_640x640.jpg
#
#  Pembe (ID: 1052)
#    One Size (ID: 200003528)
#     https://ae01.alicdn.com/kf/Sa850466f75124bd98f9faaac976035c56/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_640x640.jpg
#
#  Mor (ID: 496)
#    One Size (ID: 200003528)
#     https://ae01.alicdn.com/kf/Sf3df6c7b12ec497996cd7a4ac60baf00V/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_640x640.jpg
#
#  Mavi (ID: 173)
#    One Size (ID: 200003528)
#     https://ae01.alicdn.com/kf/S864b48f43fa54df8a58629d86a01232aQ/Yaz-i-ek-ekli-sa-pen-e-k-pekbal-firkete-tokalar-m-kad-n-k-zlar.jpg_640x640.jpg
#
# ...

# %%
import json

# JSON verisini tanımlama (örnek devam ediyor)
json_data = '''
{
  "skuJson": [
    {
      "freightExt": "{\"d0\":\"0.40\",\"d1\":\"USD\",\"itemScene\":\"newGlobal\",\"p0\":\"12000035198564756\",\"p1\":\"0.38\",\"p10\":[218307,526666,86914,218119,86884,1098872,84809,299658,242413,648839,526940,306961,273138,306962,111478,307155,720850,339135,721847],\"p16\":true,\"p18\":\"default\",\"p3\":\"USD\",\"p4\":\"990000\",\"p5\":\"0\",\"p6\":\"null\",\"p7\":\"{\\\"scItemId\\\":\\\"771737268350\\\"}\",\"p9\":\"US $0.38\"}",
      "promotionEnhanceInfoBanner": {
        "content": "<span style=\"color: #D3031C;\">5+ adet, ekstra %1 indirim</span>",
        "icon": "https://ae01.alicdn.com/kf/S8d6bb1d75fb34f2a97934793b4506c25T/340x62.png"
      },
      "salable": true,
      "skuAttr": "14:173;5:200003528",
      "skuId": 12000035198564756,
      "skuIdStr": "12000035198564756",
      "skuPropIds": "173,200003528",
      "skuVal": {
        "availQuantity": 863,
        "bulkOrder": 5,
        "discount": "45",
        "discountTips": "-45%",
        "hideOriPrice": false,
        "inventory": 863,
        "isActivity": true,
        "optionalWarrantyPrice": [],
        "skuActivityAmount": {
          "currency": "TRY",
          "formatedAmount": "13,80TL",
          "value": 13.8
        },
        "skuActivityAmountLocal": "13,80TL|13|80",
        "skuAmount": {
          "currency": "TRY",
          "formatedAmount": "24,85TL",
          "value": 24.85
        },
        "skuAmountLocal": "24,85TL|24|85",
        "skuCalPrice": "0.72",
        "skuExtraTips": "5+ adet, ekstra %1 indirim"
      }
    }
  ]
}
'''

# JSON verisini yükleme
data = json.loads(json_data)

# SKU listesi
sku_list = data["skuJson"]

# Tabloya dönüştürülecek bilgilerin başlıkları
headers = ["SKU ID", "SKU Attribute", "Avail Quantity", "Bulk Order", "Discount", "Discount Tips", "SKU Activity Amount", "SKU Cal Price", "SKU Extra Tips", "Promotion Banner Content", "Promotion Banner Icon"]

# Tablo başlığını yazdırma
print(" | ".join(headers))

# Her SKU için bilgileri yazdırma
for sku in sku_list:
    sku_id = sku["skuId"]
    sku_attr = sku["skuAttr"]
    avail_quantity = sku["skuVal"]["availQuantity"]
    bulk_order = sku["skuVal"]["bulkOrder"]
    discount = sku["skuVal"]["discount"]
    discount_tips = sku["skuVal"]["discountTips"]
    sku_activity_amount = sku["skuVal"]["skuActivityAmount"]["formatedAmount"]
    sku_cal_price = sku["skuVal"]["skuCalPrice"]
    sku_extra_tips = sku["skuVal"]["skuExtraTips"]
    promotion_banner_content = sku["promotionEnhanceInfoBanner"]["content"]
    promotion_banner_icon = sku["promotionEnhanceInfoBanner"]["icon"]

    # Her bir SKU için bir satır oluşturma
    row = [
        str(sku_id),
        sku_attr,
        str(avail_quantity),
        str(bulk_order),
        discount,
        discount_tips,
        sku_activity_amount,
        sku_cal_price,
        sku_extra_tips,
        promotion_banner_content,
        promotion_banner_icon
    ]

    # Satırı formatlı şekilde yazdırma
    print(" | ".join(row))
